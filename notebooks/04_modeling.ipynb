# %% [markdown]
# # 04 — Predictive Modeling & TimeSeries Cross-Validation
# ### Climate-Smart Agriculture: Bi-Seasonal Paddy Yield Forecasting
# **Module:** IT41033 Nature Inspired Algorithms (NIA)
#
# ---
# This notebook trains and tunes 4 predictive regression architectures:
# 1. **Baseline Linear Regression**
# 2. **Random Forest Regressor** (tuned via `TimeSeriesSplit`)
# 3. **LightGBM Regressor** (tuned via `TimeSeriesSplit`)
# 4. **Deep Neural Network (MLP)** (3 hidden layers with early stopping)
#
# **Research Question 2**: *Do advanced ensemble methods outperform traditional deep neural networks on tabular climate/agricultural series?*

# %%
import sys
sys.path.insert(0, '..')

from src.models import train_and_evaluate_all_models

model_results = train_and_evaluate_all_models(save_best=True)
metrics_df = model_results['metrics_df']
display(metrics_df)
