# %% [markdown]
# # 05 — Model Evaluation & Feature Importance Analysis
# ### Climate-Smart Agriculture: Bi-Seasonal Paddy Yield Forecasting
# **Module:** IT41033 Nature Inspired Algorithms (NIA)
#
# ---
# This notebook analyzes model generalization, feature attribution, and empirical answers to the research questions.

# %%
import sys
sys.path.insert(0, '..')
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

artifacts = joblib.load('../models/all_models.pkl')
display(artifacts['metrics_df'])

print('Best Model Selected:', joblib.load('../models/best_model.pkl')['model_name'])

# %% [markdown]
# ## Visual Validation Diagnostics
# ![Model Predictions vs Actual](../reports/figures/07_model_predictions_vs_actual.png)
# ![Feature Importance](../reports/figures/08_feature_importance_comparison.png)
